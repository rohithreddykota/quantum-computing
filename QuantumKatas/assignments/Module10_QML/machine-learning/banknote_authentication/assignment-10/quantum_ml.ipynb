# %% [markdown]
# ## <a id='toc1_1_'></a>[Quantum Machine Learning](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Quantum Machine Learning](#toc1_1_)
#   - [Environment Setup](#toc1_2_)
#   - [About Dataset](#toc1_3_)
#   - [Load train and test data](#toc1_4_)
#   - [Initialize the weights and bias for the training](#toc1_5_)
#   - [Load Qunatum Machine Learning Package](#toc1_6_)
#   - [Train Model](#toc1_7_)
#   - [Validate model](#toc1_8_)
#   - [Classify](#toc1_9_)
#   - [Conclusion](#toc1_10_)
#   - [References](#toc1_11_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_2_'></a>[Environment Setup](#toc0_)
#
# - Executed in docker container built using the Dockerfile in the QuantumKatas repository.
# - It had few issues with iqsharp and proj deps. Fixed it. See [PR](https://github.com/microsoft/QuantumKatas/pull/900)

# %% [markdown]
# ## <a id='toc1_3_'></a>[About Dataset](#toc0_)
#
# The task is to implement a quantum machine learning algorithm for banknote authentication. The dataset is available at [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/banknote+authentication).
#
# The dataset contains 1372 data points, each with 4 features and a label. The task is to classify the data points into two classes: genuine and forged banknotes.

# %% [markdown]
# ## <a id='toc1_4_'></a>[Load train and test data](#toc0_)

# %%
import json

# load data from json file
with open('train_test_split.json', 'r') as f:
    data = json.load(f)
    
X_train_list = data['train']['features']
y_train_list = data['train']['labels']

X_test_list = data['test']['features']
y_test_list = data['test']['labels']

# %% [markdown]
# ## <a id='toc1_5_'></a>[Initialize the weights and bias for the training](#toc0_)
#
# This following block of code initializes the weights and bias for the training randomly with uniform distribution.

# %%
## Generate Initial Weights

import random
# Set a seed for reproducibility
random.seed(42)

# Function to generate random numbers between 0 and 5
def generate_random_numbers():
    return random.uniform(0, 5)


initial_weights = []
for i in range(8):
    arr = []
    for i in range(8):
        arr.append(generate_random_numbers())
    initial_weights.append(arr)
    
initial_weights
# Out:
# [[3.1971339922894186,
#   0.12505377611333468,
#   1.3751465918455963,
#   1.1160536907441139,
#   3.682356070820062,
#   3.3834974371145563,
#   4.460897838524227,
#   0.43469416314708076],
#  [2.1096090984263522,
#   0.14898609719035172,
#   1.0931898740180168,
#   2.526776440516812,
#   0.13267984841931812,
#   0.9941882534332425,
#   3.249422188897616,
#   2.724707403016083],
#  [1.1022031102034835,
#   2.946328419379544,
#   4.047152283389133,
#   0.032493798390305084,
#   4.02909625916404,
#   3.4906969749411343,
#   1.7012525825899594,
#   0.7773974990589078],
#  [4.786065361033906,
#   1.682972725563134,
#   0.46372921690073954,
#   0.48358188416732006,
#   4.237471831737299,
#   3.0186301568344556,
#   4.035641366371901,
#   3.6486589334690893],
#  [2.6811404572735036,
#   4.865578819896853,
#   1.8926718860417675,
#   2.760203156366135,
#   4.1470233212649745,
#   3.0925987618212303,
#   4.308534501553886,
#   2.88676072628381],
#  [3.5228591810746175,
#   0.22912191827831108,
#   1.1394913782577343,
#   1.4469398180105357,
#   0.3989598846181375,
#   1.163954431805151,
#   0.5050071470486456,
#   1.3898680155504606],
#  [3.178422221322001,
#   1.8241608948504213,
#   1.850904835584413,
#   1.0475351538574385,
#   1.334889110245567,
#   4.68327293856247,
#   3.2401769262329676,
#   3.045655028334941],
#  [0.8556932409904849,
#   3.645633989751746,
#   0.817012468809642,
#   1.897277208788239,
#   4.9476167531829764,
#   3.1999987992704644,
#   2.784748718873231,
#   3.423071254949373]]

# %% [markdown]
# ## <a id='toc1_6_'></a>[Load Qunatum Machine Learning Package](#toc0_)

# %%
import qsharp
qsharp.packages.add("Microsoft.Quantum.MachineLearning::0.28.302812")
# Out:
# Preparing Q# environment...
# Adding package Microsoft.Quantum.MachineLearning::0.28.302812.

# %%
qsharp.reload()
# Out:
# Reloading workspace.

# %% [markdown]
# ## <a id='toc1_7_'></a>[Train Model](#toc0_)

# %%
from Microsoft.Quantum.Samples import (
    TrainModel, ValidateModel, ClassifyModel
)

# %%
weights, bias = TrainModel.simulate(
    trainingVectors=X_train_list,
    trainingLabels=y_train_list,
    initialParameters=initial_weights,
    verbose=True
)
# Out:
# Ready to train.
# Classifier structure length: 4
# Mapped length: 8
# Example Map - Mapped[0]: SequentialModel(([ControlledRotation(((0, []), PauliX, 4)),ControlledRotation(((0, []), PauliZ, 5)),ControlledRotation(((1, []), PauliX, 1)),ControlledRotation(((1, []), PauliX, 0))], [3.1971339922894186,0.12505377611333468,1.3751465918455963,1.1160536907441139,3.682356070820062,3.3834974371145563,4.460897838524227,0.43469416314708076], 0))
# Samples length: 1097
# Mapped length: 8
#   Beginning training at start point #0...
#     Pre-encoding samples...
#     Beginning epoch 1.
#         Beginning minibatch 0 of 1.
#       Estimating gradient at sample 0...
#       Estimating gradient at sample 1...
#       Estimating gradient at sample 2...
#       Estimating gradient at sample 3...
#       Estimating gradient at sample 4...
#       Estimating gradient at sample 5...
#       Estimating gradient at sample 6...
#       Estimating gradient at sample 7...
#       Estimating gradient at sample 8...
#       Estimating gradient at sample 9...
#       Estimating gradient at sample 10...
#       Estimating gradient at sample 11...
#       Estimating gradient at sample 12...
#       Estimating gradient at sample 13...
#       Estimating gradient at sample 14...
#       Estimating gradient at sample 15...
#       Estimating gradient at sample 16...
#       Estimating gradient at sample 17...
#       Estimating gradient at sample 18...
#       Estimating gradient at sample 19...
#       Estimating gradient at sample 20...
#       Estimating gradient at sample 21...
#       Estimating gradient at sample 22...
#       Estimating gradient at sample 23...
#       Estimating gradient at sample 24...
#       Estimating gradient at sample 25...
#       Estimating gradient at sample 26...
#       Estimating gradient at sample 27...
#       Estimating gradient at sample 28...
#       Estimating gradient at sample 29...
#       Estimating gradient at sample 30...
#       Estimating gradient at sample 31...
#       Estimating gradient at sample 32...
#       Estimating gradient at sample 33...
#       Estimating gradient at sample 34...
#       Estimating gradient at sample 35...
#       Estimating gradient at sample 36...
#       Estimating gradient at sample 37...
#       Estimating gradient at sample 38...
#       Estimating gradient at sample 39...
#       Estimating gradient at sample 40...
#       Estimating gradient at sample 41...
#       Estimating gradient at sample 42...
#       Estimating gradient at sample 43...
#       Estimating gradient at sample 44...
#       Estimating gradient at sample 45...
#       Estimating gradient at sample 46...
#       Estimating gradient at sample 47...
#       Estimating gradient at sample 48...
#       Estimating gradient at sample 49...
#       Estimating gradient at sample 50...
#       Estimating gradient at sample 51...
#       Estimating gradient at sample 52...
#       Estimating gradient at sample 53...
#       Estimating gradient at sample 54...
#       Estimating gradient at sample 55...
#       Estimating gradient at sample 56...
#       Estimating gradient at sample 57...
#       Estimating gradient at sample 58...
#       Estimating gradient at sample 59...
#       Estimating gradient at sample 60...
#       Estimating gradient at sample 61...
#       Estimating gradient at sample 268...
#       Estimating gradient at sample 269...
#       Estimating gradient at sample 270...
#       Estimating gradient at sample 271...
#       Estimating gradient at sample 272...
#       Estimating gradient at sample 273...
#       Estimating gradient at sample 274...
#       Estimating gradient at sample 275...
#       Estimating gradient at sample 276...
#       Estimating gradient at sample 277...
#       Estimating gradient at sample 278...
#       Estimating gradient at sample 279...
#       Estimating gradient at sample 280...
#       Estimating gradient at sample 281...
#       Estimating gradient at sample 282...
#       Estimating gradient at sample 283...
#       Estimating gradient at sample 284...
#       Estimating gradient at sample 285...
#       Estimating gradient at sample 286...
#       Estimating gradient at sample 287...
#       Estimating gradient at sample 288...
#       Estimating gradient at sample 289...
#       Estimating gradient at sample 290...
#       Estimating gradient at sample 291...
#       Estimating gradient at sample 292...
#       Estimating gradient at sample 293...
#       Estimating gradient at sample 294...
#       Estimating gradient at sample 295...
#       Estimating gradient at sample 296...
#       Estimating gradient at sample 297...
#       Estimating gradient at sample 298...
#       Estimating gradient at sample 299...
#       Estimating gradient at sample 300...
#       Estimating gradient at sample 301...
#       Estimating gradient at sample 302...
#       Estimating gradient at sample 303...
#       Estimating gradient at sample 304...
#       Estimating gradient at sample 305...
#       Estimating gradient at sample 306...
#       Estimating gradient at sample 307...
#       Estimating gradient at sample 308...
#       Estimating gradient at sample 309...
#       Estimating gradient at sample 310...
#       Estimating gradient at sample 311...
#       Estimating gradient at sample 312...
#       Estimating gradient at sample 313...
#       Estimating gradient at sample 314...
#       Estimating gradient at sample 315...
#       Estimating gradient at sample 316...
#       Estimating gradient at sample 317...
#       Estimating gradient at sample 318...
#       Estimating gradient at sample 319...
#       Estimating gradient at sample 320...
#       Estimating gradient at sample 321...
#       Estimating gradient at sample 322...
#       Estimating gradient at sample 323...
#       Estimating gradient at sample 324...
#       Estimating gradient at sample 325...
#       Estimating gradient at sample 326...
#       Estimating gradient at sample 327...
#       Estimating gradient at sample 328...
#       Estimating gradient at sample 329...
#       Estimating gradient at sample 330...
#       Estimating gradient at sample 331...
#       Estimating gradient at sample 332...
#       Estimating gradient at sample 333...
#       Estimating gradient at sample 334...
#       Estimating gradient at sample 335...
#       Estimating gradient at sample 336...
#       Estimating gradient at sample 337...
#       Estimating gradient at sample 338...
#       Estimating gradient at sample 339...
#       Estimating gradient at sample 340...
#       Estimating gradient at sample 341...
#       Estimating gradient at sample 342...
#       Estimating gradient at sample 343...
#       Estimating gradient at sample 344...
#       Estimating gradient at sample 345...
#       Estimating gradient at sample 346...
#       Estimating gradient at sample 347...
#       Estimating gradient at sample 348...
#       Estimating gradient at sample 349...
#       Estimating gradient at sample 350...
#       Estimating gradient at sample 351...
#       Estimating gradient at sample 352...
#       Estimating gradient at sample 353...
#       Estimating gradient at sample 354...
#       Estimating gradient at sample 355...
#       Estimating gradient at sample 356...
#       Estimating gradient at sample 357...
#       Estimating gradient at sample 358...
#       Estimating gradient at sample 359...
#       Estimating gradient at sample 360...
#       Estimating gradient at sample 361...
#       Estimating gradient at sample 362...
#       Estimating gradient at sample 363...
#       Estimating gradient at sample 364...
#       Estimating gradient at sample 365...
#       Estimating gradient at sample 366...
#       Estimating gradient at sample 367...
#       Estimating gradient at sample 368...
#       Estimating gradient at sample 369...
#       Estimating gradient at sample 370...
#       Estimating gradient at sample 371...
#       Estimating gradient at sample 372...
#       Estimating gradient at sample 373...
#       Estimating gradient at sample 374...
#       Estimating gradient at sample 375...
#       Estimating gradient at sample 376...
#       Estimating gradient at sample 377...
#       Estimating gradient at sample 378...
#       Estimating gradient at sample 379...
#       Estimating gradient at sample 380...
#       Estimating gradient at sample 381...
#       Estimating gradient at sample 382...
#       Estimating gradient at sample 383...
#       Estimating gradient at sample 384...
#       Estimating gradient at sample 385...
#       Estimating gradient at sample 386...
#       Estimating gradient at sample 387...
#       Estimating gradient at sample 388...
#       Estimating gradient at sample 389...
#       Estimating gradient at sample 390...
#       Estimating gradient at sample 391...
#       Estimating gradient at sample 392...
#       Estimating gradient at sample 393...
#       Estimating gradient at sample 394...
#       Estimating gradient at sample 395...
#       Estimating gradient at sample 396...
#       Estimating gradient at sample 397...
#       Estimating gradient at sample 398...
#       Estimating gradient at sample 399...
#       Estimating gradient at sample 400...
#       Estimating gradient at sample 401...
#       Estimating gradient at sample 402...
#       Estimating gradient at sample 403...
#       Estimating gradient at sample 404...
#       Estimating gradient at sample 405...
#       Estimating gradient at sample 406...
#       Estimating gradient at sample 407...
#       Estimating gradient at sample 408...
#       Estimating gradient at sample 409...
#       Estimating gradient at sample 410...
#       Estimating gradient at sample 411...
#       Estimating gradient at sample 412...
#       Estimating gradient at sample 413...
#       Estimating gradient at sample 414...
#       Estimating gradient at sample 415...
#       Estimating gradient at sample 416...
#       Estimating gradient at sample 417...
#       Estimating gradient at sample 418...
#       Estimating gradient at sample 419...
#       Estimating gradient at sample 420...
#       Estimating gradient at sample 421...
#       Estimating gradient at sample 422...
#       Estimating gradient at sample 423...
#       Estimating gradient at sample 424...
#       Estimating gradient at sample 425...
#       Estimating gradient at sample 426...
#       Estimating gradient at sample 427...
#       Estimating gradient at sample 428...
#       Estimating gradient at sample 429...
#       Estimating gradient at sample 430...
#       Estimating gradient at sample 431...
#       Estimating gradient at sample 432...
#       Estimating gradient at sample 433...
#       Estimating gradient at sample 434...
#       Estimating gradient at sample 435...
#       Estimating gradient at sample 436...
#       Estimating gradient at sample 437...
#       Estimating gradient at sample 438...
#       Estimating gradient at sample 439...
#       Estimating gradient at sample 440...
#       Estimating gradient at sample 441...
#       Estimating gradient at sample 442...
#       Estimating gradient at sample 443...
#       Estimating gradient at sample 444...
#       Estimating gradient at sample 445...
#       Estimating gradient at sample 446...
#       Estimating gradient at sample 447...
#       Estimating gradient at sample 448...
#       Estimating gradient at sample 449...
#       Estimating gradient at sample 450...
#       Estimating gradient at sample 451...
#       Estimating gradient at sample 452...
#       Estimating gradient at sample 453...
#       Estimating gradient at sample 454...
#       Estimating gradient at sample 455...
#             Observed good parameter update... estimating and possibly committing.
#     Beginning epoch 2.
#         Beginning minibatch 0 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 1 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 2 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 3 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 4 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 5 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 6 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 7 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 8 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 9 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 10 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 11 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 12 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 13 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 14 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 15 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 16 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 17 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 18 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 19 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 20 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 21 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 22 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 23 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 24 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 25 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 26 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 27 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 28 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 29 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 30 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 31 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 32 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 33 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 34 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 35 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 36 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 37 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 38 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 39 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 40 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 41 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 42 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 43 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 44 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 45 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 46 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 47 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 48 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 49 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 50 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 51 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 52 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 53 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 54 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 55 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 56 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 57 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 58 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 59 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 60 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 61 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 62 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 63 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 64 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 65 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 66 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 67 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 68 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 69 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 70 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 71 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 72 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 73 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 74 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 75 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 76 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 77 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 78 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 79 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 80 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 81 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 82 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 83 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 84 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 85 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 86 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 87 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 88 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 89 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 90 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 91 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 92 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 93 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 94 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 95 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 96 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 97 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 98 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 99 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 100 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 101 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 102 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 103 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 104 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 105 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 106 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 107 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 108 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 109 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 110 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 111 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 112 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 113 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 114 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 115 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 116 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 117 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 118 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 119 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 120 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 121 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 122 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 123 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 124 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 125 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 126 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 127 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 128 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 129 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 130 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 131 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 132 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 133 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 134 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 135 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 136 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 137 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 138 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 139 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 140 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 141 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 142 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 143 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 144 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 145 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 146 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 147 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 148 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 149 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 150 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 151 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 152 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 153 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 154 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 155 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 156 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 157 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 158 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 159 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 160 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 161 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 162 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 163 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 164 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 165 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 166 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 167 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 168 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 169 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 170 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
# ...
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
#         Beginning minibatch 456 of 456.
#       Estimating gradient at sample 0...
#             Observed good parameter update... estimating and possibly committing.
# Training complete!

# %% [markdown]
# ## <a id='toc1_8_'></a>[Validate model](#toc0_)

# %%
miss_rate = ValidateModel.simulate(
    validationVectors=X_test_list,
    validationLabels=y_test_list,
    parameters=weights, bias=bias
)

print(f"Miss rate: {miss_rate}")
# Out:
# Miss rate: 0.1454545454545

# %% [markdown]
# ## <a id='toc1_9_'></a>[Classify](#toc0_)

# %%
actual_labels = y_test_list
classified_labels = ClassifyModel.simulate(
    samples=X_test_list,
    parameters=weights, bias=bias,
    tolerance=0.005, nMeasurements=10_000
)

import pandas as pd
df = pd.DataFrame({'actual': actual_labels, 'classified': classified_labels})
df = df[df['actual'] != df['classified']]

df
# Out:
#      actual  classified
# 11        1           0
# 13        1           0
# 17        1           0
# 19        1           0
# 28        0           1
# 38        1           0
# 41        1           0
# 44        1           0
# 72        1           0
# 77        1           0
# 82        1           0
# 85        0           1
# 104       1           0
# 114       1           0
# 120       1           0
# 122       1           0
# 124       1           0
# 127       1           0
# 130       1           0
# 134       0           1
# 137       0           1
# 147       1           0
# 148       1           0
# 153       0           1
# 160       1           0
# 164       1           0
# 193       1           0
# 201       1           0
# 205       1           0
# 228       1           0
# 230       1           0
# 232       1           0
# 233       0           1
# 235       1           0
# 244       1           0
# 252       1           0
# 254       1           0
# 263       1           0
# 264       1           0
# 268       1           0

# %% [markdown]
# ## <a id='toc1_10_'></a>[Conclusion](#toc0_)

# %% [markdown]
# Accuracy of the classical model:
#
#     Accuracy: 98%
#     Time taken to train: 10.1 ms
#
# Accuracy of using Quantum model:
#
#     Accuracy: 85.54%
#     Num Qubits Used: 3
#     Time taken to train: ~12Hours

# %% [markdown]
# ## <a id='toc1_11_'></a>[References](#toc0_)
#
# - The paper ['Circuit-centric quantum classifiers', by Maria Schuld, Alex Bocharov, Krysta Svore and Nathan Wiebe](https://arxiv.org/abs/1804.00633). Used it to understand the concept of quantum classifiers and the implementation of the quantum circuit for the same.
# - [QunatumKatas/tutorials/QuantumClassification](https://github.com/microsoft/QuantumKatas/tree/main/tutorials/QuantumClassification) provided the basic structure of the code and the implementation of the quantum circuit for the quantum classifier.
#
# - [Quantum Machine Learning Samples](https://github.com/microsoft/Quantum/tree/main/samples/machine-learning) from Microsoft Quantum repository.
